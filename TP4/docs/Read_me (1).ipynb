# %%
# Convolutional Neural Networks (CNN) Report

This project presents a concise study of **Convolutional Neural Networks (CNNs)**, covering core concepts, architectures, and training techniques, along with illustrative figures.

## Contents
- Fundamentals of CNNs (Convolution, Feature Maps, Pooling)
- CNN Architectures (LeNet, AlexNet, Inception, ResNet, MobileNet, EfficientNet)
- Advanced Training Techniques
  - Data Augmentation
  - Transfer Learning
  - Batch Normalization
  - Dropout
  - Degradation Problem

## Figures Included
- Input image and corresponding feature map
- Simplified residual block
- Effect of regularization on training vs overfitting

## Tools & Technologies
- LaTeX (TikZ, graphicx)
- CNN concepts based on deep learning literature
