# %%
README = """
PROJECT SUMMARY


This repository contains two machine learning projects implemented in Python.
1. Wine Quality Prediction (MLP from Scratch)


Description:
A regression model that predicts wine quality using a Multi-Layer Perceptron (MLP)
implemented entirely from scratch using NumPy (no deep learning frameworks).

Dataset:
- winequality-red.csv
- winequality-white.csv

Key Steps:
- Merge red and white wine datasets
- Feature standardization using StandardScaler
- Custom MLP with ReLU hidden layers and linear output
- Mini-batch gradient descent with backpropagation
- Evaluation using MSE, RMSE, and R²

Outputs:
- mlp_loss_curve.png          (training vs validation loss)
- mlp_pred_vs_actual.png      (predicted vs actual values)
- mlp_params.npz              (saved model parameters)

2. Adult Income Classification (Neural Network)

Description:
A binary classification task predicting whether income exceeds 50K using the
Adult Census dataset with full preprocessing and a neural network.
Dataset:
- adult.data
- adult.test

Key Steps:
- Data cleaning and label processing
- Numerical feature scaling and categorical one-hot encoding
- Train/validation/test split
- Deep MLP using TensorFlow with BatchNorm, Dropout, Early Stopping
- Automatic fallback to Logistic Regression if TensorFlow is unavailable
- Evaluation using Accuracy, Precision, Recall, F1-score, and ROC-AUC

Outputs:
- Preprocessing pipeline (joblib)
- Trained neural network or logistic regression model
- Prediction CSV files saved in the artifacts/ directory
Requirements
- Python 3.x
- NumPy
- Pandas
- Scikit-learn
- Matplotlib
- TensorFlow (optional, for Adult MLP)
Notes
- Both projects use fixed random seeds for reproducibility
- Artifacts are saved locally for later reuse or evaluation
- Code is designed to run end-to-end with minimal configuration
"""

if __name__ == "__main__":
    print(README)
# Out:
# PROJECT SUMMARY
# ...
#
# This repository contains two machine learning projects implemented in Python.
#
#
# --------------------------------------------------
# 1. Wine Quality Prediction (MLP from Scratch)
# --------------------------------------------------
#
# Description:
# A regression model that predicts wine quality using a Multi-Layer Perceptron (MLP)
# implemented entirely from scratch using NumPy (no deep learning frameworks).
#
# Dataset:
# - winequality-red.csv
# - winequality-white.csv
#
# Key Steps:
# - Merge red and white wine datasets
# - Feature standardization using StandardScaler
# - Custom MLP with ReLU hidden layers and linear output
# - Mini-batch gradient descent with backpropagation
# - Evaluation using MSE, RMSE, and R²
#
# Outputs:
# - mlp_loss_curve.png          (training vs validation loss)
# - mlp_pred_vs_actual.png      (predicted vs actual values)
# - mlp_params.npz              (saved model parameters)
#
#
# ...
